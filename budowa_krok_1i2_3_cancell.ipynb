# %% [markdown]
# # **MILESTONE 1 i 2**

# %% [markdown]
# ## **Cel biznesowy:** Segmentacja klientów banku na podstawie ich zachowań transakcyjnych i typów kont w celu personalizacji ofert marketingowych i zwiększenia retencji klientów
#
# **Korzyści wynikające dla banku z racji takiego pogrupowania klientów:**
#
# - Możliwość kierowania odpowiednich ofert do odpowiednich klientów (np. lokaty dla klientów z dużym saldem).
#
# - Identyfikacja klientów wysokiego ryzyka lub niskiej aktywności.
#
# - Możliwość tworzenia kampanii retencyjnych dla segmentów o niskim zaangażowaniu.

# %% [markdown]
# ### Wczytanie ramki danych

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.model_selection import train_test_split

df = pd.read_csv("data/banking_dataset.csv")

# %% [markdown]
# ## **Eksploracja i wstępna analiza danych**

# %%
df.head()
# Out:
#                                                             Account ID;Customer Name;Account Type;Branch;Transaction Type;Transaction Amount;Account Balance;Currency
# ACC00001;Amanda Pugh;Recurring Deposit;New York... 19;36676                                             19;GBP
# ACC00002;Amanda Wilcox;Recurring Deposit;Housto... 77;28582                                             82;USD
# ACC00003;Kimberly Valenzuela;Current;New York;C... 74;76599                                             56;GBP
# ACC00004;Sonia Ballard;Recurring Deposit;Philad... 53;62317                                              6;INR
# ACC00005;Erika Russell;Current;Philadelphia;Deb... 21;INR                                                  NaN

# %% [markdown]
# Widzimy, że ramka danych po zapisaniu w pliku csv, nie ładuje się dobrze. Na szczęście jest na to rozwiązanie:

# %%
df = pd.read_csv("data/banking_dataset.csv", sep=";")

# %%
df.head()
# Out:
#   Account ID        Customer Name       Account Type        Branch  \
# 0   ACC00001          Amanda Pugh  Recurring Deposit      New York
# 1   ACC00002        Amanda Wilcox  Recurring Deposit       Houston
# 2   ACC00003  Kimberly Valenzuela            Current      New York
# 3   ACC00004        Sonia Ballard  Recurring Deposit  Philadelphia
# 4   ACC00005        Erika Russell            Current  Philadelphia
#
#   Transaction Type Transaction Amount Account Balance Currency
# 0            Debit            2687,19        36676,19      GBP
# 1            Debit            3886,77        28582,82      USD
# 2           Credit            2438,74        76599,56      GBP
# 3           Credit            2758,53         62317,6      INR
# 4            Debit               3287        85515,21      INR

# %%
df.tail()
# Out:
#      Account ID      Customer Name   Account Type        Branch  \
# 9995   ACC09996      Richard Davis  Fixed Deposit      New York
# 9996   ACC09997       Lauren Weber        Savings       Chicago
# 9997   ACC09998      Nichole Stout  Fixed Deposit       Houston
# 9998   ACC09999  Kristen Wilkinson  Fixed Deposit  Philadelphia
# 9999   ACC10000     Brian Sandoval  Fixed Deposit  Philadelphia
#
#      Transaction Type Transaction Amount Account Balance Currency
# 9995            Debit             400,96        38035,17      USD
# 9996            Debit             3736,7        60682,41      EUR
# 9997           Credit            4002,91        36136,11      USD
# 9998            Debit              866,9        35644,82      GBP
# 9999            Debit            3932,81        32357,51      GBP

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Account ID          10000 non-null  object
#  1   Customer Name       10000 non-null  object
#  2   Account Type        10000 non-null  object
#  3   Branch              10000 non-null  object
#  4   Transaction Type    10000 non-null  object
#  5   Transaction Amount  10000 non-null  object
#  6   Account Balance     10000 non-null  object
#  7   Currency            10000 non-null  object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# Wszysktie kolumny są typu object - potrzebna zamiana wartości numerycznych na wartości numeryczne

# %%
print(df.isnull().sum())
# Out:
# Account ID            0
# Customer Name         0
# Account Type          0
# Branch                0
# Transaction Type      0
# Transaction Amount    0
# Account Balance       0
# Currency              0
# dtype: int64

# %% [markdown]
# Brak pustych wartości

# %%
df.describe()
# Out:
#        Account ID     Customer Name Account Type        Branch  \
# count       10000             10000        10000         10000
# unique      10000              9323            4             8
# top      ACC00001  William Williams      Savings  Philadelphia
# freq            1                 7         2580          1288
#
#        Transaction Type Transaction Amount Account Balance Currency
# count             10000              10000           10000    10000
# unique                2               9896            9995        5
# top              Credit            3398,97        21317,69      JPY
# freq               5114                  3               2     2041

# %% [markdown]
# AccountID jest takie samo, imię może się powtarzać więc powtarzające się wartości wcale nie oznaczają, że to ta sama osoba. Zatem konta są unikalne.

# %% [markdown]
# ## Po wstępnej analizie kolumn, usunięte zostaną kolumny 'Account ID' oraz 'Customer Name'.

# %%
df = df.drop(['Account ID', 'Customer Name'], axis = 1)

# %%
df.head()
# Out:
#         Account Type        Branch Transaction Type Transaction Amount  \
# 0  Recurring Deposit      New York            Debit            2687,19
# 1  Recurring Deposit       Houston            Debit            3886,77
# 2            Current      New York           Credit            2438,74
# 3  Recurring Deposit  Philadelphia           Credit            2758,53
# 4            Current  Philadelphia            Debit               3287
#
#   Account Balance Currency
# 0        36676,19      GBP
# 1        28582,82      USD
# 2        76599,56      GBP
# 3         62317,6      INR
# 4        85515,21      INR

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Możemy teraz przejść do dalszej eksploracji danych, najpierw zmieńmy typy danych w kolumnach, aby móc operować na zmiennych liczbowych

# %%
#df['Transaction Amount'] = pd.to_numeric(df['Transaction Amount'], errors='coerce')
#df['Account Balance'] = pd.to_numeric(df['Account Balance'], errors='coerce')

df['Transaction Amount'] = df['Transaction Amount'].str.replace(',', '.').astype(float)
df['Account Balance'] = df['Account Balance'].str.replace(',', '.').astype(float)

# %% [markdown]
# Zamiana wartości liczbowych na typ float

# %%
print(df.dtypes)
# Out:
# Account Type           object
# Branch                 object
# Transaction Type       object
# Transaction Amount    float64
# Account Balance       float64
# Currency               object
# dtype: object

# %% [markdown]
# Nowe typy danych

# %%
for col in ['Account Type', 'Branch', 'Transaction Type', 'Currency']:
    print(f"\nUnikalne wartości w kolumnie {col}:")
    print(df[col].value_counts())
# Out:
# Unikalne wartości w kolumnie Account Type:
# Account Type
# Savings              2580
# Current              2529
# Fixed Deposit        2489
# Recurring Deposit    2402
# Name: count, dtype: int64
#
# Unikalne wartości w kolumnie Branch:
# Branch
# Philadelphia    1288
# Phoenix         1274
# Los Angeles     1268
# Houston         1259
# New York        1256
# Chicago         1239
# San Antonio     1233
# San Diego       1183
# Name: count, dtype: int64
#
# Unikalne wartości w kolumnie Transaction Type:
# Transaction Type
# Credit    5114
# Debit     4886
# Name: count, dtype: int64
#
# Unikalne wartości w kolumnie Currency:
# Currency
# JPY    2041
# EUR    2039
# USD    2035
# GBP    1958
# INR    1927
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=df['Transaction Amount'])
plt.title('Boxplot of Transaction Amount')
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Account Balance'])
plt.title('Boxplot of Account Balance')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Nie ma widocznych żadnych outlierów dla wartości liczbowych.**

# %%
plt.figure(figsize=(12, 5))

# Transaction amount
plt.subplot(1, 2, 1)
sns.histplot(df['Transaction Amount'], bins=30, kde=True)
plt.title('Histogram of Transaction Amount')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')

# Acc balance
plt.subplot(1, 2, 2)
sns.histplot(df['Account Balance'], bins=30, kde=True)
plt.title('Histogram of Account Balance')
plt.xlabel('Account Balance')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Count plots for categorical variables
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
sns.countplot(x='Account Type', data=df)
plt.title('Distribution of Account Type')
plt.xticks(rotation=45)

plt.subplot(2, 2, 2)
sns.countplot(x='Branch', data=df)
plt.title('Distribution of Branch')
plt.xticks(rotation=45)

plt.subplot(2, 2, 3)
sns.countplot(x='Transaction Type', data=df)
plt.title('Distribution of Transaction Type')

plt.subplot(2, 2, 4)
sns.countplot(x='Currency', data=df)
plt.title('Distribution of Currency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Dla każdej zmiennej kategorycznej zliczenia możliwych wartości są rozłożone mniej więcej po równo.

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Macierz korelacji")
plt.show()

# %% [markdown]
# Pomiędzy zmiennymi numerycznymi nie zachodzi korelacja

# %%
print(df.groupby('Account Type')['Transaction Amount'].mean())

print(df.groupby('Currency')['Account Balance'].mean())
# Out:
# Account Type
# Current              2502.820059
# Fixed Deposit        2546.617151
# Recurring Deposit    2512.312627
# Savings              2536.010089
# Name: Transaction Amount, dtype: float64
# Currency
# EUR    50502.715473
# GBP    49906.100516
# INR    51049.621271
# JPY    49827.480314
# USD    50091.525027
# Name: Account Balance, dtype: float64

# %% [markdown]
# Średnia wartość transakcji jest taka sama dla każdego typu konta. Średni stan konta jest taki sam dla każdej waluty.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Account Type', y='Account Balance', data=df)
plt.title('Account Balance by Account Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Brak outlierów. Rozkład stanu konta w zależności od typu konta

# %%
# Cross-tabulation of Account Type and Transaction Type
print(pd.crosstab(df['Account Type'], df['Transaction Type']))
# Out:
# Transaction Type   Credit  Debit
# Account Type
# Current              1323   1206
# Fixed Deposit        1266   1223
# Recurring Deposit    1206   1196
# Savings              1319   1261

# %% [markdown]
# Po równo.

# %% [markdown]
# # **Inżynieria cech**

# %% [markdown]
# ## **Zamiana na jedną walutę i ponowne przeprowadzenie analizy**

# %%
exchange_rates = {'USD': 1.0, 'EUR': 1.08, 'GBP': 1.27, 'INR': 0.012, 'JPY': 0.0066}

# Zamiana na USD
df['Transaction Amount USD'] = df.apply(lambda x: float(x['Transaction Amount']) * exchange_rates.get(x['Currency'], 1.0), axis=1)
df['Account Balance USD'] = df.apply(lambda x: float(x['Account Balance']) * exchange_rates.get(x['Currency'], 1.0), axis=1)

# sprawdzamy czy dizała
print(df[['Transaction Amount USD', 'Account Balance USD']].describe())
# Out:
#        Transaction Amount USD  Account Balance USD
# count            10000.000000         10000.000000
# mean              1704.556596         33910.047464
# std               1870.159242         37213.913721
# min                  0.082434             0.897336
# 25%                 26.736683           535.726967
# 50%                950.329000         18802.265000
# 75%               3277.854375         65177.548200
# max               6347.510800        126968.999300

# %%
sns.boxplot(x=df['Transaction Amount USD'])
plt.title('Boxplot of Transaction Amount USD')
plt.show()

# %% [markdown]
# brak outlierów

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=df['Transaction Amount USD'])
plt.title('Boxplot of Transaction Amount')
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Account Balance USD'])
plt.title('Boxplot of Account Balance')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

# Histogram dla Transaction Amount
plt.subplot(1, 2, 1)
sns.histplot(df['Transaction Amount USD'], bins=30, kde=True)
plt.title('Histogram of Transaction Amount in USD')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')

# Histogram dla Account Balance
plt.subplot(1, 2, 2)
sns.histplot(df['Account Balance USD'], bins=30, kde=True)
plt.title('Histogram of Account Balance in USD')
plt.xlabel('Account Balance')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Bardzo mocna skośność, można rozważyć logarytmowanie - lub wykluczenie zmiennej (nwm)

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Macierz korelacji")
plt.show()

# %% [markdown]
# **Przeskalowanie wartości** dla wartości numerycznych sprowadzając wszystko do jednej waluty daje ciekawe informacje. Jednak mimo wszystko wydaje się, że może być to mało wartościowa zmienna.

# %% [markdown]
# ## Nowa zmienna

# %%
df['Balance_to_Transaction_Ratio'] = df['Account Balance'] / df['Transaction Amount']

# %% [markdown]
# Może być wrażliwe na outliery. Dzielimy jaki jest stan konta przez kwotę transakcji. Im wyższe ktoś ma ratio, tym bardziej ryzykownym klientem jest.

# %%
sns.boxplot(df['Balance_to_Transaction_Ratio'])
# Out:
# <Axes: >

# %% [markdown]
# Posiada wartości odstające.

# %%
sns.histplot(df['Balance_to_Transaction_Ratio'], bins=30, kde=True)
plt.title('Histogram of Balance to Transaction Ratio')
plt.xlabel('Balance_to_Transaction')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['Log_Balance_to_Transaction_Ratio'] = np.log1p(df['Balance_to_Transaction_Ratio'].clip(lower=1e-6))

# %%
sns.histplot(df['Log_Balance_to_Transaction_Ratio'], bins=30, kde=True)
plt.title('Histogram of Log Balance to Transaction Ratio')
plt.xlabel('Balance_to_Transaction')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.boxplot(df['Log_Balance_to_Transaction_Ratio'])
# Out:
# <Axes: >

# %%
print(df[df['Account Balance USD'] < 0].shape)  
print(df[df['Transaction Amount USD'] <= 0].shape)
# Out:
# (0, 10)
# (0, 10)

# %% [markdown]
# Brak ujemnych sald

# %% [markdown]
# Zmiana zmiennych kategorycznych

# %%
df['Transaction Type'] = df['Transaction Type'].map({'Debit': 0, 'Credit': 1})

# %%
df = pd.get_dummies(df, columns=['Branch'], prefix='Branch')

# %% [markdown]
# Zmienne odpowiadające za to czy ktoś robi więcej dużych czy mniej transakcji (też poproszę o opinię)

# %%
df['Account_Type_Original'] = df['Account Type'].copy()
df = pd.get_dummies(df, columns=['Account Type'], prefix='Account_Type')
df['Transaction_Amount_Relative_to_Mean'] = df['Transaction Amount USD'] / df.groupby('Account_Type_Original')['Transaction Amount USD'].transform('mean')
df = df.drop('Account_Type_Original', axis=1)

# %%
df = pd.get_dummies(df, columns=['Currency'], prefix='Currency')

# %%
df.describe()
# Out:
#        Transaction Type  Transaction Amount  Account Balance  \
# count      10000.000000        10000.000000     10000.000000
# mean           0.511400         2524.564298     50269.794260
# std            0.499895         1444.318039     29057.726646
# min            0.000000           10.970000       101.890000
# 25%            0.000000         1263.912500     24863.487500
# 50%            1.000000         2544.655000     50790.475000
# 75%            1.000000         3781.757500     75128.187500
# max            1.000000         4999.790000     99975.590000
#
#        Transaction Amount USD  Account Balance USD  \
# count            10000.000000         10000.000000
# mean              1704.556596         33910.047464
# std               1870.159242         37213.913721
# min                  0.082434             0.897336
# 25%                 26.736683           535.726967
# 50%                950.329000         18802.265000
# 75%               3277.854375         65177.548200
# max               6347.510800        126968.999300
#
#        Balance_to_Transaction_Ratio  Log_Balance_to_Transaction_Ratio  \
# count                  10000.000000                      10000.000000
# mean                      61.379967                          3.093531
# std                      252.298729                          1.220871
# min                        0.026799                          0.026447
# 25%                        9.917744                          2.390389
# 50%                       19.914487                          3.040442
# 75%                       39.532359                          3.702101
# max                     8163.276436                          9.007523
#
#        Transaction_Amount_Relative_to_Mean
# count                         10000.000000
# mean                              1.000000
# std                               1.097227
# min                               0.000049
# 25%                               0.015712
# 50%                               0.556743
# 75%                               1.922764
# max                               3.758784

# %%
correlation_matrix = df[['Transaction Amount USD', 'Account Balance USD', 'Log_Balance_to_Transaction_Ratio']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.describe()
# Out:
#        Transaction Type  Transaction Amount  Account Balance  \
# count      10000.000000        10000.000000     10000.000000
# mean           0.511400         2524.564298     50269.794260
# std            0.499895         1444.318039     29057.726646
# min            0.000000           10.970000       101.890000
# 25%            0.000000         1263.912500     24863.487500
# 50%            1.000000         2544.655000     50790.475000
# 75%            1.000000         3781.757500     75128.187500
# max            1.000000         4999.790000     99975.590000
#
#        Transaction Amount USD  Account Balance USD  \
# count            10000.000000         10000.000000
# mean              1704.556596         33910.047464
# std               1870.159242         37213.913721
# min                  0.082434             0.897336
# 25%                 26.736683           535.726967
# 50%                950.329000         18802.265000
# 75%               3277.854375         65177.548200
# max               6347.510800        126968.999300
#
#        Balance_to_Transaction_Ratio  Log_Balance_to_Transaction_Ratio  \
# count                  10000.000000                      10000.000000
# mean                      61.379967                          3.093531
# std                      252.298729                          1.220871
# min                        0.026799                          0.026447
# 25%                        9.917744                          2.390389
# 50%                       19.914487                          3.040442
# 75%                       39.532359                          3.702101
# max                     8163.276436                          9.007523
#
#        Transaction_Amount_Relative_to_Mean
# count                         10000.000000
# mean                              1.000000
# std                               1.097227
# min                               0.000049
# 25%                               0.015712
# 50%                               0.556743
# 75%                               1.922764
# max                               3.758784

# %% [markdown]
# ## NOTATNIK WRZUCONY DO CHATA I ZEBY ZROBIL COKOLWIEK WIEC NWM CO TO ALE COS ROBI WIEC ZOSTAWIAM XD

# %% [markdown]
# # WSZYSTKO DO WYRZUCENIA IMO, możęsz zerknącć

# %%
from sklearn.preprocessing import StandardScaler
numeric_cols = ['Transaction Amount USD', 'Account Balance USD', 'Log_Balance_to_Transaction_Ratio', 'Transaction_Amount_Relative_to_Mean']
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Wybór cech do klasteryzacji
features = ['Transaction Amount USD', 'Account Balance USD', 'Log_Balance_to_Transaction_Ratio', 'Transaction_Amount_Relative_to_Mean'] + \
           [col for col in df.columns if col.startswith('Account_Type_') or col.startswith('Currency_')]

# Określenie optymalnej liczby klastrów
inertias = []
silhouette_scores = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df[features])
    inertias.append(kmeans.inertia_)
    if k > 1:
        silhouette_scores.append(silhouette_score(df[features], kmeans.labels_))

# Wykres elbow
plt.plot(range(2, 10), inertias, marker='o')
plt.title('Elbow Plot')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Klasteryzacja z wybraną liczbą klastrów
kmeans = KMeans(n_clusters=4, random_state=42)
df['Cluster'] = kmeans.fit_predict(df[features])
# Out:
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df[features])
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['Cluster'], cmap='viridis')
plt.title('Clusters Visualization (PCA)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D  # Dodaj ten import na górze komórki

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(
    pca_result[:, 0], pca_result[:, 1], pca_result[:, 2],
    c=df['Cluster'], cmap='viridis', s=50
)
ax.set_title('Clusters Visualization (PCA 3D)')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.set_zlabel('PCA Component 3')
fig.colorbar(scatter, ax=ax, label='Cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[333], line 6
#       3 fig = plt.figure(figsize=(8, 6))
#       4 ax = fig.add_subplot(111, projection='3d')
#       5 scatter = ax.scatter(
# ----> 6     pca_result[:, 0], pca_result[:, 1], pca_result[:, 2],
#       7     c=df['Cluster'], cmap='viridis', s=50
#       8 )
#       9 ax.set_title('Clusters Visualization (PCA 3D)')
#      10 ax.set_xlabel('PCA Component 1')
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
sns.boxplot(x='Account_Type_Savings', y='Log_Balance_to_Transaction_Ratio', data=df)
plt.title('Balance to Transaction Ratio by Savings Account')
plt.show()

# %%
silhouette_avg = silhouette_score(df[features], df['Cluster'])
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.2675115829798535

# %%
Q1 = df['Log_Balance_to_Transaction_Ratio'].quantile(0.25)
Q3 = df['Log_Balance_to_Transaction_Ratio'].quantile(0.75)
IQR = Q3 - Q1
df_cut = df[~((df['Log_Balance_to_Transaction_Ratio'] < (Q1 - 1.5 * IQR)) | (df['Log_Balance_to_Transaction_Ratio'] > (Q3 + 1.5 * IQR)))]

# %%
sns.boxplot(x='Account_Type_Savings', y='Log_Balance_to_Transaction_Ratio', data=df_cut)
plt.title('Balance to Transaction Ratio by Savings Account')
plt.show()

# %%
features_cut = ['Transaction Amount USD', 'Account Balance USD', 'Log_Balance_to_Transaction_Ratio', 'Transaction_Amount_Relative_to_Mean'] + \
           [col for col in df_cut.columns if col.startswith('Account_Type_') or col.startswith('Currency_')]

# Określenie optymalnej liczby klastrów
inertias = []
silhouette_scores = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_cut[features])
    inertias.append(kmeans.inertia_)
    if k > 1:
        silhouette_scores.append(silhouette_score(df_cut[features], kmeans.labels_))

# Wykres elbow
plt.plot(range(2, 10), inertias, marker='o')
plt.title('Elbow Plot')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Klasteryzacja z wybraną liczbą klastrów
kmeans = KMeans(n_clusters=4, random_state=42)
df_cut['Cluster'] = kmeans.fit_predict(df_cut[features])
# Out:
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\48530\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\48530\AppData\Local\Temp\ipykernel_19436\2810673746.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['Cluster'] = kmeans.fit_predict(df_cut[features])

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_cut[features])
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df_cut['Cluster'], cmap='viridis')
plt.title('Clusters Visualization (PCA)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
# Out:
# Text(0, 0.5, 'PCA Component 2')

# %%
cluster_summary = df.groupby('Cluster').mean()
print(cluster_summary)
# Out:
#          Transaction Type  Transaction Amount  Account Balance  \
# Cluster
# 0                0.494071         3301.985522     21229.973473
# 1                0.494195          982.702155     62780.776295
# 2                0.523496         2428.271346     46656.466541
# 3                0.518072         3572.475301     71365.973966
#
#          Transaction Amount USD  Account Balance USD  \
# Cluster
# 0                      1.027236            -0.291320
# 1                     -0.341552             0.850725
# 2                     -0.856486            -0.865878
# 3                      1.256318             1.262961
#
#          Balance_to_Transaction_Ratio  Log_Balance_to_Transaction_Ratio  \
# Cluster
# 0                            6.932558                         -1.010294
# 1                          209.051890                          1.142217
# 2                           34.076117                         -0.093186
# 3                           21.266243                         -0.038605
#
#          Branch_Chicago  Branch_Houston  Branch_Los Angeles  ...  \
# Cluster                                                      ...
# 0              0.141728        0.117448            0.121400  ...
# 1              0.128218        0.115598            0.136295  ...
# 2              0.114427        0.130169            0.131109  ...
# 3              0.123996        0.134538            0.112952  ...
#
#          Account_Type_Current  Account_Type_Fixed Deposit  \
# Cluster
# 0                    0.264822                    0.245624
# 1                    0.255427                    0.244321
# 2                    0.254699                    0.247885
# 3                    0.235944                    0.258534
#
#          Account_Type_Recurring Deposit  Account_Type_Savings  \
# Cluster
# 0                              0.241107              0.248447
# 1                              0.231701              0.268551
# 2                              0.242011              0.255404
# 3                              0.243976              0.261546
#
#          Transaction_Amount_Relative_to_Mean  Currency_EUR  Currency_GBP  \
# Cluster
# 0                                   1.027762      0.348955      0.269339
# 1                                  -0.341550      0.316002      0.275618
# 2                                  -0.856477      0.030780      0.025846
# 3                                   1.255830      0.333333      0.414157
#
#          Currency_INR  Currency_JPY  Currency_USD
# Cluster
# 0            0.000000      0.000000      0.381705
# 1            0.023725      0.023221      0.361434
# 2            0.441729      0.468750      0.032895
# 3            0.000000      0.000000      0.252510
#
# [4 rows x 25 columns]

# %%
silhouette_avg = silhouette_score(df_cut[features], df_cut['Cluster'])
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.2753531093665416

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Zastosowanie DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
df['Cluster_DBSCAN'] = dbscan.fit_predict(df)

# Liczba klastrów i szumu
n_clusters = len(set(df['Cluster_DBSCAN'])) - (1 if -1 in df['Cluster_DBSCAN'] else 0)
n_noise = list(df['Cluster_DBSCAN']).count(-1)
print(f'Liczba klastrów: {n_clusters}')
print(f'Liczba punktów szumu: {n_noise}')
# Out:
# Liczba klastrów: 1
# Liczba punktów szumu: 10000

# %%
from sklearn.cluster import DBSCAN
import numpy as np

# Zastosowanie DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
df_cut['Cluster_DBSCAN'] = dbscan.fit_predict(df_cut)

# Liczba klastrów i szumu
n_clusters = len(set(df_cut['Cluster_DBSCAN'])) - (1 if -1 in df_cut['Cluster_DBSCAN'] else 0)
n_noise = list(df['Cluster_DBSCAN']).count(-1)
print(f'Liczba klastrów: {n_clusters}')
print(f'Liczba punktów szumu: {n_noise}')
# Out:
# Liczba klastrów: 1
# Liczba punktów szumu: 10000
# C:\Users\48530\AppData\Local\Temp\ipykernel_19436\3565297904.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['Cluster_DBSCAN'] = dbscan.fit_predict(df_cut)

# %%
from sklearn.neighbors import NearestNeighbors

neighbors = NearestNeighbors(n_neighbors=5)
neighbors_fit = neighbors.fit(df)
distances, indices = neighbors_fit.kneighbors(df)
distances = np.sort(distances[:, 4], axis=0)
plt.plot(distances)
plt.title('K-NN Distances for eps Selection')
plt.xlabel('Points')
plt.ylabel('Distance to 5th Nearest Neighbor')
plt.show()

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['Cluster_DBSCAN'], cmap='viridis')
plt.title('DBSCAN Clusters (PCA)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)
pca_result = pca.fit_transform(df)
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(
    pca_result[:, 0], pca_result[:, 1], pca_result[:, 2],
    c=df['Cluster_DBSCAN'], cmap='viridis', s=50
)
ax.set_title('DBSCAN Clusters (PCA 3D)')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.set_zlabel('PCA Component 3')
fig.colorbar(scatter, ax=ax, label='Cluster')
plt.show()

# %%
pca = PCA(n_components=0.95)  # Zachowaj 95% wariancji
df_pca = pca.fit_transform(df)
print(f'Liczba wybranych składowych: {pca.n_components_}')
print(f'Wyjaśniona wariancja: {pca.explained_variance_ratio_}')
# Out:
# Liczba wybranych składowych: 1
# Wyjaśniona wariancja: [0.99746208]

# %%
pca = PCA(n_components=0.95)  # Zachowaj 95% wariancji
df_pca = pca.fit_transform(df_cut)
print(f'Liczba wybranych składowych: {pca.n_components_}')
print(f'Wyjaśniona wariancja: {pca.explained_variance_ratio_}')
# Out:
# Liczba wybranych składowych: 1
# Wyjaśniona wariancja: [0.99763812]
